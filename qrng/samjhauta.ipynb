# %%
from qiskit import QuantumCircuit
from qiskit_aer import AerSimulator
qc = QuantumCircuit(1, 1)
qc.h(0)
qc.measure(0, 0)

result = AerSimulator().run(qc, shots=1).result()
random_bit = int(list(result.get_counts().keys())[0])

print(f"Quantum random number: {random_bit}")
# Out:
# Quantum random number: 0

# %%
from qiskit import QuantumCircuit
from qiskit_aer import AerSimulator
qc = QuantumCircuit(2, 2)
qc.h(0)
qc.h(1)
qc.measure([0, 1], [0, 1])

result = AerSimulator().run(qc, shots=1).result()
bit_string = list(result.get_counts().keys())[0]
random_num = int(bit_string, 2)

print(f"2-qubit quantum random number: {random_num} (binary: {bit_string})")
# Out:
# 2-qubit quantum random number: 1 (binary: 01)

# %%
from qiskit import QuantumCircuit
from qiskit_aer import AerSimulator
qc = QuantumCircuit(3, 3)
qc.h(0); qc.h(1); qc.h(2)
qc.measure([0,1,2], [0,1,2])
result = AerSimulator().run(qc, shots=1).result()
bit_string = list(result.get_counts().keys())[0]
random_num = int(bit_string, 2)

print(f"3-qubit random number: {random_num} (binary: {bit_string})")
# Out:
# 3-qubit random number: 2 (binary: 010)

# %%
from qiskit import QuantumCircuit
from qiskit_aer import AerSimulator

def quantum_0_to_9():
    """One-line function for random 0-9"""
    while True:
        qc = QuantumCircuit(4,4)
        for i in range(4): qc.h(i)
        qc.measure(range(4),range(4))
        n = int(list(AerSimulator().run(qc,shots=1).result().get_counts().keys())[0],2)
        if n < 10: return n
for i in range(4):
    print(quantum_0_to_9())
# Out:
# 9
# 6
# 8
# 5

# %%
from qiskit import QuantumCircuit
from qiskit_aer import AerSimulator

def quantum_random(n):
    """One-line function to generate random number with n qubits"""
    qc = QuantumCircuit(n, n)
    for i in range(n): qc.h(i)
    qc.measure(range(n), range(n))
    result = AerSimulator().run(qc, shots=1).result()
    return int(list(result.get_counts().keys())[0], 2)
    
print("N-Qubit Quantum Random Numbers:")
for n in [1, 2, 3, 4]:
    print(f"{n} qubit(s): {quantum_random(n)}")
# Out:
# N-Qubit Quantum Random Numbers:
# 1 qubit(s): 0
# 2 qubit(s): 0
# 3 qubit(s): 0
# 4 qubit(s): 9
